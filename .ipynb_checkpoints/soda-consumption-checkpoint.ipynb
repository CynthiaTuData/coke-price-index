# %%
import pandas as pd
import re

# %%
consumption = pd.read_csv('consumption.csv')
consumption
# Out:
#          country  servings
# 0         Mexico       634
# 1  United States       618
# 2         Brazil       280
# 3          Japan       116
# 4         Russia       108
# 5          China        56
# 6        Nigeria        49
# 7       Pakistan        49
# 8      Indonesia        18
# 9          India        18

# %%
import camelot
tables = camelot.read_pdf('International-Drinks-Data.pdf')
tables[0]
tables[0].to_csv('sugar-data.csv')

# %%
sugar = pd.read_csv('sugar-data.csv')
sugar = sugar[sugar['Unnamed: 1']=='Coca Cola']
sugar.head()
# Out:
#    Country\nProduct \nSugars (g) per 330ml* serving \nTeaspoons sugar (g) equiv/330ml* serving  \
# 8                                              Canada
# 9                                               Japan
# 10                                              India
# 11                                         Bangladesh
# 12                                        South Korea
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3
# 8   Coca Cola        39.0        10.0
# 9   Coca Cola        37.0         9.0
# 10  Coca Cola        36.0         9.0
# 11  Coca Cola        36.0         9.0
# 12  Coca Cola        36.0         9.0

# %%
# Cleaning the data
sugar.columns =['country','brand','sugar/serving','tspoon/serving']
sugar.head()
# Out:
#         country      brand  sugar/serving  tspoon/serving
# 8        Canada  Coca Cola           39.0            10.0
# 9         Japan  Coca Cola           37.0             9.0
# 10        India  Coca Cola           36.0             9.0
# 11   Bangladesh  Coca Cola           36.0             9.0
# 12  South Korea  Coca Cola           36.0             9.0

# %%
# Converting oz to ml and match the metric
# consumption data uses 8-oz bottle, and sugar data uses 330ml bottle
oz =
